# %%
a=10
print(type(a))

b=10.5
print(type(b))

c="aditya"
print(type(c))

d=True
print(type(d))

f=[1,2,3]
print(type(f))

h={"name":"aditya"}
print(type(h))

i={"aditya"}
print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
