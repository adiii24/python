# %% [markdown]
# <a href="https://colab.research.google.com/github/adiii24/python/blob/main/Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
c=a+b
print("addition=",c)

a=100
name="aditya"
print("type:",type(a))
print("type:",type(name))

a=10
b=float(a)
print("value=",a)
print("after type casting to float=",b)
print("type of b=",type(b))

a=10
b=5
print(a>5 and b>2)
print(a>5 or b>2)
print(not(a>5))
# Out:
# addition= 30
# type: <class 'int'>
# type: <class 'str'>
# value= 10
# after type casting to float= 10.0
# type of b= <class 'float'>
# True
# True
# False
